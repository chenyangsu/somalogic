# %%
import pandas as pd
import os

ROOT_DIR = os.getcwd()

file = 'infe_417-soma_data=normalized-nat_log_tranf=FALSE-standardize=FALSE-remove_outliers=FALSE.csv'
file_path = os.path.join(ROOT_DIR, 'results', 'datasets', file)
df = pd.read_csv(file_path, low_memory=False)
df
# Out:
# /mnt/c/Users/user/PycharmProjects/somalogic
#          SubjectID anonymized_patient_id   PlateId SampleGroup sex  \
# 0    03201-20_CHUM                CHUM_1  P0027948        CHUM   F
# 1    03202-20_CHUM                CHUM_5  P0027953        CHUM   M
# 2    03204-20_CHUM                CHUM_7  P0027948        CHUM   M
# 3    03205-20_CHUM                CHUM_8  P0027951        CHUM   M
# 4    03208-20_CHUM               CHUM_10  P0027952        CHUM   M
# ..             ...                   ...       ...         ...  ..
# 412    VAP09674-20               JGH_794  P0027957         JGH   M
# 413    VAP09676-20               JGH_792  P0027950         JGH   M
# 414    VAP09678-20               JGH_790  P0027955         JGH   M
# 415    VAP09679-20               JGH_789  P0027946         JGH   M
# 416    VAP09680-20               JGH_788  P0027956         JGH   M
#
#      age_at_diagnosis  Days_symptom_update3  ProcessTime  A2  A3  ...  \
# 0                  68                   9.0         0.83   1   1  ...
# 1                  48                  13.0         2.83   0   1  ...
# 2                  33                  11.0         5.42   1   1  ...
# 3                  56                   2.0         6.90   0   0  ...
# 4                  66                  11.0         3.25   1   1  ...
# ..                ...                   ...          ...  ..  ..  ...
# 412                69                   4.0         1.58   0   0  ...
# 413                76                   3.0         3.58   0   0  ...
# 414                82                  10.0         2.92   0   0  ...
# 415                92                   4.0        19.08   0   0  ...
# 416                62                   5.0         4.42   1   1  ...
#
#      KIAA1467.9981.18  PRSS35.9983.97 YIPF6.9984.12 NPW.9986.14  \
# 0               389.3           295.7         562.8      1182.6
# 1               385.5           277.9         544.0       274.2
# 2               418.7           299.9         532.0       274.1
# 3               380.7           371.8         561.4      2725.4
# 4               449.3           378.5         605.1       386.5
# ..                ...             ...           ...         ...
# 412             347.4           483.7         641.0      1994.6
# 413             409.6          2583.7         648.3      4566.8
# 414             443.3           449.6         681.1      2779.8
# 415             481.9           394.8         692.2      5772.6
# 416             404.9           501.3         636.4      1870.0
#
#     LRRC24.9989.12  ZNF264.9993.11  ATP4B.9994.217  DUT.9995.6 UBXN4.9997.12  \
# 0            442.3          1595.8          1559.5      9822.0       20394.7
# 1            363.9           995.3          1331.6     10258.4       37942.8
# 2            840.8          1462.8          1570.8      9692.3       28594.9
# 3            470.9          1289.0          1442.7      3874.1       23521.1
# 4            602.4          1697.9          1831.2      4651.8       21177.9
# ..             ...             ...             ...         ...           ...
# 412          496.9           837.3          1261.3      2132.7        5932.1
# 413         7651.1           940.4          1309.0      1463.4        4432.0
# 414          519.9          1160.0          1418.3      2257.4       10626.6
# 415          612.7           831.6          1309.1      2218.0       20250.0
# 416          409.8          1077.5          1319.4      2518.7        9078.4
#
#      IRF6.9999.1
# 0         2802.6
# 1         8192.5
# 2         6297.5
# 3         5056.0
# 4         4260.4
# ..           ...
# 412       1759.8
# 413       1429.7
# 414       1903.6
# 415       1699.2
# 416       1740.1
#
# [417 rows x 5326 columns]

# %%
from tableone import TableOne
columns = ['age_at_diagnosis', 'sex', 'ProcessTime', 'SampleGroup', 'A2', 'A3']
mytable = TableOne(df, columns=columns)
print(mytable.tabulate(tablefmt="github"))
# Out:
# |                             |      | Missing   | Overall     |
# |-----------------------------|------|-----------|-------------|
# | n                           |      |           | 417         |
# | age_at_diagnosis, mean (SD) |      | 0         | 65.3 (18.4) |
# | sex, n (%)                  | F    | 0         | 200 (48.0)  |
# |                             | M    |           | 217 (52.0)  |
# | ProcessTime, mean (SD)      |      | 0         | 9.7 (13.4)  |
# | SampleGroup, n (%)          | CHUM | 0         | 105 (25.2)  |
# |                             | JGH  |           | 312 (74.8)  |
# | A2, n (%)                   | 0    | 0         | 324 (77.7)  |
# |                             | 1    |           | 93 (22.3)   |
# | A3, n (%)                   | 0    | 0         | 202 (48.4)  |
# |                             | 1    |           | 215 (51.6)  |
# /home/csu/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(max(df['age_at_diagnosis']))
print(min(df['age_at_diagnosis']))
# Out:
# 99
# 20
# /home/csu/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import statistics
statistics.median(df['age_at_diagnosis'])
# Out:
# /home/csu/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 67

# %%
outcomes = ['A2', 'A3']
for outcome in outcomes:
    columns = ['age_at_diagnosis', 'sex', 'ProcessTime', 'SampleGroup']

    df_cases = df[df[outcome] == 1]  # cases
    df_controls = df[df[outcome] == 0]
    print(f'{outcome} cases')
    print(f"max age {max(df_cases['age_at_diagnosis'])}")
    print(f"min age {min(df_cases['age_at_diagnosis'])}")

    mytable = TableOne(df_cases, columns=columns)
    print(mytable.tabulate(tablefmt="github"))
    
    print(f'{outcome} controls')
    print(f"max age {max(df_controls['age_at_diagnosis'])}")
    print(f"min age {min(df_controls['age_at_diagnosis'])}")

    mytable = TableOne(df_controls, columns=columns)
    print(mytable.tabulate(tablefmt="github"))
# Out:
# /home/csu/anaconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# A2 cases
# max age 93
# min age 28
# |                             |      | Missing   | Overall     |
# |-----------------------------|------|-----------|-------------|
# | n                           |      |           | 93          |
# | age_at_diagnosis, mean (SD) |      | 0         | 66.7 (16.5) |
# | sex, n (%)                  | F    | 0         | 36 (38.7)   |
# |                             | M    |           | 57 (61.3)   |
# | ProcessTime, mean (SD)      |      | 0         | 7.0 (6.3)   |
# | SampleGroup, n (%)          | CHUM | 0         | 32 (34.4)   |
# |                             | JGH  |           | 61 (65.6)   |
# A2 controls
# max age 99
# min age 20
# |                             |      | Missing   | Overall     |
# |-----------------------------|------|-----------|-------------|
# | n                           |      |           | 324         |
# | age_at_diagnosis, mean (SD) |      | 0         | 64.9 (18.9) |
# | sex, n (%)                  | F    | 0         | 164 (50.6)  |
# |                             | M    |           | 160 (49.4)  |
# | ProcessTime, mean (SD)      |      | 0         | 10.4 (14.8) |
# | SampleGroup, n (%)          | CHUM | 0         | 73 (22.5)   |
# |                             | JGH  |           | 251 (77.5)  |
# A3 cases
# max age 99
# min age 22
# |                             |      | Missing   | Overall     |
# |-----------------------------|------|-----------|-------------|
# | n                           |      |           | 215         |
# | age_at_diagnosis, mean (SD) |      | 0         | 68.0 (17.1) |
# | sex, n (%)                  | F    | 0         | 100 (46.5)  |
# |                             | M    |           | 115 (53.5)  |
# | ProcessTime, mean (SD)      |      | 0         | 7.7 (8.4)   |
# | SampleGroup, n (%)          | CHUM | 0         | 67 (31.2)   |
# |                             | JGH  |           | 148 (68.8)  |
# A3 controls
# max age 98
# min age 20
# |                             |      | Missing   | Overall     |
# |-----------------------------|------|-----------|-------------|
# | n                           |      |           | 202         |
# | age_at_diagnosis, mean (SD) |      | 0         | 62.5 (19.3) |
# | sex, n (%)                  | F    | 0         | 100 (49.5)  |
# |                             | M    |           | 102 (50.5)  |
# | ProcessTime, mean (SD)      |      | 0         | 11.8 (17.0) |
# | SampleGroup, n (%)          | CHUM | 0         | 38 (18.8)   |
# |                             | JGH  |           | 164 (81.2)  |
